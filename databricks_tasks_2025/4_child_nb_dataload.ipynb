# %%
# %python

import requests

# URL to fetch the CSV file
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"

# Perform API call
response = requests.get(url)

# Raise an error if the request fails
response.raise_for_status()

# The CSV content as text
csv_text = response.text

# Destination path inside the Databricks volume
dest_path = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# Write the data into the volume
dbutils.fs.put(dest_path, csv_text, overwrite=True)

print("File successfully written to:", dest_path)
